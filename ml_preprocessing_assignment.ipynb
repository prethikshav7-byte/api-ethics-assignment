# %% [markdown]
# <a href="https://colab.research.google.com/github/prethikshav7-byte/api-ethics-assignment/blob/main/ml_preprocessing_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, RobustScaler

data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
    'City': ['Mumbai', 'Delhi', 'Chennai', 'Mumbai', 'Delhi'],
    'Size': ['Small', 'Large', 'Medium', 'Large', 'Small'],
    'Age': [25, 45, 32, 60, 28],
    'Fare': [15, 300, 85, 450, 20]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Gender     City    Size  Age  Fare
# 0    Male   Mumbai   Small   25    15
# 1  Female    Delhi   Large   45   300
# 2  Female  Chennai  Medium   32    85
# 3    Male   Mumbai   Large   60   450
# 4  Female    Delhi   Small   28    20

# %% [markdown]
# Task 1 — Categorical Encoding
#  1. Label Encoding → Gender

# %%
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %% [markdown]
# 2. One-Hot Encoding → City (drop one column)

# %%
df = pd.get_dummies(df, columns=['City'], drop_first=True)

# %% [markdown]
# Ordinal Encoding → Size (Custom Order)

# %%
size_mapping = {'Small': 0, 'Medium': 1, 'Large': 2}
df['Size'] = df['Size'].map(size_mapping)

# %% [markdown]
# Task 2 — Feature Scaling

# %%
scaler = RobustScaler()

df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])
# Out:
#    Gender     City    Size       Age      Fare
# 0    Male   Mumbai   Small -0.411765 -0.250000
# 1  Female    Delhi   Large  0.764706  0.767857
# 2  Female  Chennai  Medium  0.000000  0.000000
# 3    Male   Mumbai   Large  1.647059  1.303571
# 4  Female    Delhi   Small -0.235294 -0.232143

# %% [markdown]
# Justification
# # RobustScaler is used because the Fare column contains an outlier (450).
# # It scales data using median and IQR, making it resistant to outliers.

# %%
print(df)
# Out:
#    Gender     City  Size       Age      Fare
# 0    Male   Mumbai     0 -0.411765 -0.250000
# 1  Female    Delhi     2  0.764706  0.767857
# 2  Female  Chennai     1  0.000000  0.000000
# 3    Male   Mumbai     2  1.647059  1.303571
# 4  Female    Delhi     0 -0.235294 -0.232143
